# %% [markdown]
# <a href="https://colab.research.google.com/github/crestrepod/Topics/blob/main/Plots.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
# !git clone https://github.com/crestrepod/Topics
sys.path.append('/content/Topics')

# %%
import pinch

# %%
#Ejercicio 1
Cp1 = [20,40,80,36]
T1 = [[80,180] , [40,130] , [60,100] , [30,120]]    
pinch.plot_pinch(Cp1,T1)
